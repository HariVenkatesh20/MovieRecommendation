# %%
import pandas as pd

# %%
movies_df=pd.read_csv('movies.csv')

# %%
movies_df.head(10)
# Out:
#                                                Title  Year  \
# 0                                            Kantara  2022
# 1                                    The Dark Knight  2008
# 2      The Lord of the Rings: The Return of the King  2003
# 3                                          Inception  2010
# 4              The Lord of the Rings: The Two Towers  2002
# 5  The Lord of the Rings: The Fellowship of the Ring  2001
# 6                                         The Matrix  1999
# 7                            The Empire Strikes Back  1980
# 8                         Terminator 2: Judgment Day  1991
# 9                                          Star Wars  1977
#
#                                     Director  \
# 0                              Rishab Shetty
# 1                          Christopher Nolan
# 2                              Peter Jackson
# 3                          Christopher Nolan
# 4                              Peter Jackson
# ...

# %%
df_cleaned = movies_df.drop(columns=['Unnamed: 8'])

# %%
movies_df.head(10)
# Out:
#                                                Title  Year  \
# 0                                            Kantara  2022
# 1                                    The Dark Knight  2008
# 2      The Lord of the Rings: The Return of the King  2003
# 3                                          Inception  2010
# 4              The Lord of the Rings: The Two Towers  2002
# 5  The Lord of the Rings: The Fellowship of the Ring  2001
# 6                                         The Matrix  1999
# 7                            The Empire Strikes Back  1980
# 8                         Terminator 2: Judgment Day  1991
# 9                                          Star Wars  1977
#
#                                     Director  \
# 0                              Rishab Shetty
# 1                          Christopher Nolan
# 2                              Peter Jackson
# 3                          Christopher Nolan
# 4                              Peter Jackson
# ...
